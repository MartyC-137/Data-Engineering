# %%
table = 'fact_salesordertransactions'
sql_query = f'select * from my_db.schema.{table} limit 5;'
print(sql_query)
# Out:
# select * from my_db.schema.fact_salesordertransactions limit 5;

# %%
warehouse = 'reporting_wh'
database = 'my_db'
schema = 'dbo'
table = 'fact_salesordertransactions'
sql_query = f'select * from {database}.{schema}.{table} limit 5;'
print(sql_query)
# Out:
# select * from my_db.dbo.fact_salesordertransactions limit 5;
